# %%
from classes import *
# Out:
# Loading Images: 100%|██████████████████████████████████████████████████████████████████| 48/48 [00:01<00:00, 43.19it/s]
# Loading Masks: 100%|██████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 262.26it/s]
# Resizing Images: 100%|███████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 2304.25it/s]
# Resizing Masks: 100%|████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 6451.12it/s]
#  (768, 1024, 3) -> (192, 256, 3)

# %%
puzzle = Puzzle(MATCH_IMGS)
# Out:
# Generating Pieces: 48it [00:00, 8065.00it/s]

# %%
corner_piece = puzzle.pieces[3]
corner_piece.insert(canvas)
corner_piece.inserted = True
canvas.display_canvas()

queue = []
queue.append(corner_piece)
# Out:
# First edge Point 1: [46.08000183 38.87744236]
# First edge Point 2: [ 44.71466827 138.7992897 ]
# Second edge Point 1: [ 44.71466827 138.7992897 ]
# Second edge Point 2: [163.83999634 140.84547043]
# Inserting piece:  3

# %%
while queue: # Keep looping over pieces as long as queue is not empty
    counter = 0 # counter to make sure that we stop bfs loop after four edges
    s = queue.pop(0) # remove top entry in the queue, this will be our first piece that we initialised with
    for edge in s.return_edge(): # check correspoinding edges of piece we popped from the queue
        counter += 1 # track that we have checked the first edge
        if edge != None and edge.connected_edge != None: # make sure that we are not working with flat edges
            for piece in puzzle.pieces: # loop through all puzzle pieces to track connecting edges
                if piece.inserted == False: # make sure we are not rechecking an already inserted piece
                    for puzzle_edge in piece.edge_list: # check all four edges of piece to be inserted
                        if puzzle_edge != None: # make sure we dont check flat edges
                            if (puzzle_edge.point1 == edge.connected_edge.parent_piece.top_edge.point1).all():
                                queue.append(piece) # enque inserted piece so that we can repeat process
                                puzzle.pieces[piece.idx].insert(canvas) # connect piece to the canvas
                                puzzle.pieces[piece.idx].inserted = True # mark inserted piece as connected
                                canvas.display_canvas()
        if counter > 4: # break bfs edge loop after checking four edges
            break
# Out:
# Inserting piece:  44
# Inserting piece:  6
# Inserting piece:  37
# Inserting piece:  31
# Inserting piece:  32
# Inserting piece:  17
# Inserting piece:  23
# Inserting piece:  10
# Inserting piece:  39
# Inserting piece:  43
# Inserting piece:  20
# Inserting piece:  11
# Inserting piece:  33
# Inserting piece:  46
# Inserting piece:  36
# Inserting piece:  27
# Inserting piece:  40
# Inserting piece:  19
# Inserting piece:  16
# Inserting piece:  8
# Inserting piece:  13
# Inserting piece:  35
# Inserting piece:  30
# Inserting piece:  15
# Inserting piece:  2
# Inserting piece:  26
# Inserting piece:  22
# Inserting piece:  25
# Inserting piece:  12
# Inserting piece:  14
# Inserting piece:  7
# Inserting piece:  0
# Inserting piece:  1
# Inserting piece:  45
# Inserting piece:  9
# Inserting piece:  41
# Inserting piece:  5
# Inserting piece:  29
# Inserting piece:  47
# Inserting piece:  28
# Inserting piece:  4
# Inserting piece:  42
# Inserting piece:  38
# Inserting piece:  34
# Inserting piece:  24
# Inserting piece:  18
# Inserting piece:  21
